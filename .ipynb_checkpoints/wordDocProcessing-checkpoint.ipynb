# %%
import pandas as pd
from docx import Document
import matplotlib.pyplot as plt
doc = Document('./raw_data/TSDR_2018-_Supplementary_Data_Report.docx')

# %%
doc.tables[1]

# %%
names = []
numbers = []

for row in doc.tables[149].rows[1:len(doc.tables[149].rows)]:
    for i in range(len(row.cells)):
        if(row.cells[i].text == ''):
            break
        if (i % 2 == 0): names.append(row.cells[i].text)
        else: numbers.append(row.cells[i].text)

names
# Out:
# ['Alberton',
#  'East Gippsland',
#  'Macedon Ranges',
#  'Queenscliffe',
#  'Alpine',
#  'Frankston',
#  'Manningham',
#  'South Gippsland',
#  'Ararat',
#  'Gannawarra',
#  'Maribyrnong',
#  'Southern Grampians',
#  'Ballarat',
#  'Glen Eira',
#  'Maroondah',
#  'Stonnington',
#  'Banyule',
#  'Glenelg',
#  'Melbourne',
#  'Strathbogie',
#  'Bass Coast',
#  'Golden Plains',
#  'Melton',
#  'Surf Coast',
#  'Baw Baw',
#  'Greater Bendigo',
#  'Mildura',
#  'Swan Hill',
#  'Bayside',
#  'Greater Dandenong',
#  'Mitchell',
#  'Towong',
#  'Benalla',
#  'Greater Geelong',
#  'Moira',
#  'Unknown LGA',
#  'Boroondara',
#  'Greater Shepparton',
#  'Monash',
#  'Wangaratta',
#  'Brimbank',
#  'Hepburn',
#  'Moonee Valley',
#  'Warrnambool',
#  'Buloke',
#  'Hindmarsh',
#  'Moorabool',
#  'Wellington',
#  'Campaspe',
#  'Hobsons Bay',
#  'Moreland',
#  'West Wimmera',
#  'Camperdown',
#  'Horsham',
#  'Mornington Peninsula',
#  'Whitehorse',
#  'Cardinia',
#  'Hume',
#  'Mount Alexander',
#  'Whittlesea',
#  'Casey',
#  'Indigo',
#  'Moyne',
#  'Wodonga',
#  'Central Goldfields',
#  'Kingston',
#  'Murrindindi',
#  'Wyndham',
#  'Colac-Otway',
#  'Knox',
#  'Nillumbik',
#  'Yarra',
#  'Corangamite',
#  'Latrobe',
#  'Northern Grampians',
#  'Yarra Ranges',
#  'Darebin',
#  'Loddon',
#  'Port Phillip',
#  'Yarriambiack',
#  'Delatite']

# %%
names
# Out:
# ['Alberton',
#  'East Gippsland',
#  'Macedon Ranges',
#  'Queenscliffe',
#  'Alpine',
#  'Frankston',
#  'Manningham',
#  'South Gippsland',
#  'Ararat',
#  'Gannawarra',
#  'Maribyrnong',
#  'Southern Grampians',
#  'Ballarat',
#  'Glen Eira',
#  'Maroondah',
#  'Stonnington',
#  'Banyule',
#  'Glenelg',
#  'Melbourne',
#  'Strathbogie',
#  'Bass Coast',
#  'Golden Plains',
#  'Melton',
#  'Surf Coast',
#  'Baw Baw',
#  'Greater Bendigo',
#  'Mildura',
#  'Swan Hill',
#  'Bayside',
#  'Greater Dandenong',
#  'Mitchell',
#  'Towong',
#  'Benalla',
#  'Greater Geelong',
#  'Moira',
#  'Unknown LGA',
#  'Boroondara',
#  'Greater Shepparton',
#  'Monash',
#  'Wangaratta',
#  'Brimbank',
#  'Hepburn',
#  'Moonee Valley',
#  'Warrnambool',
#  'Buloke',
#  'Hindmarsh',
#  'Moorabool',
#  'Wellington',
#  'Campaspe',
#  'Hobsons Bay',
#  'Moreland',
#  'West Wimmera',
#  'Camperdown',
#  'Horsham',
#  'Mornington Peninsula',
#  'Whitehorse',
#  'Cardinia',
#  'Hume',
#  'Mount Alexander',
#  'Whittlesea',
#  'Casey',
#  'Indigo',
#  'Moyne',
#  'Wodonga',
#  'Central Goldfields',
#  'Kingston',
#  'Murrindindi',
#  'Wyndham',
#  'Colac-Otway',
#  'Knox',
#  'Nillumbik',
#  'Yarra',
#  'Corangamite',
#  'Latrobe',
#  'Northern Grampians',
#  'Yarra Ranges',
#  'Darebin',
#  'Loddon',
#  'Port Phillip',
#  'Yarriambiack']

# %% [markdown]
# we want table 22.1 (index 59), 23.1 (64), 51.1, 41.1 (124), 47.1, 81.1, 79.1, 71.1

# %%
len(namesTeachers)
# Out:
# 80

# %%
len(namesStudents)
# Out:
# 80

# %%
namesStudents
# Out:
# ['Alpine',
#  'Gannawarra',
#  'Mansfield',
#  'Queenscliffe',
#  'Ararat',
#  'Glen Eira',
#  'Maribyrnong',
#  'South Gippsland',
#  'Ballarat',
#  'Glenelg',
#  'Maroondah',
#  'Southern Grampians',
#  'Banyule',
#  'Golden Plains',
#  'Melbourne',
#  'Stonnington',
#  'Bass Coast',
#  'Greater Bendigo',
#  'Melton',
#  'Strathbogie',
#  'Baw Baw',
#  'Greater Dandenong',
#  'Mildura',
#  'Surf Coast',
#  'Bayside',
#  'Greater Geelong',
#  'Mitchell',
#  'Swan Hill',
#  'Benalla',
#  'Greater Shepparton',
#  'Moira',
#  'Towong',
#  'Boroondara',
#  'Hepburn',
#  'Monash',
#  'Unincorporated Vic',
#  'Brimbank',
#  'Hindmarsh',
#  'Moonee Valley',
#  'Wangaratta',
#  'Buloke',
#  'Hobsons Bay',
#  'Moorabool',
#  'Warrnambool',
#  'Campaspe',
#  'Horsham',
#  'Moreland',
#  'Wellington',
#  'Cardinia',
#  'Hume',
#  'Mornington Peninsula',
#  'West Wimmera',
#  'Casey',
#  'Indigo',
#  'Mount Alexander',
#  'Whitehorse',
#  'Central Goldfields',
#  'Kingston',
#  'Moyne',
#  'Whittlesea',
#  'Colac-Otway',
#  'Knox',
#  'Murrindindi',
#  'Wodonga',
#  'Corangamite',
#  'Latrobe',
#  'Nillumbik',
#  'Wyndham',
#  'Darebin',
#  'Loddon',
#  'Northern Grampians',
#  'Yarra',
#  'East Gippsland',
#  'Macedon Ranges',
#  'Port Phillip',
#  'Yarra Ranges',
#  'Frankston',
#  'Manningham',
#  'Pyrenees',
#  'Yarriambiack']

# %%
for row in doc.tables[124].rows[1:len(doc.tables[124].rows)]:
    for cells in row.cells:
        if(cells.text == ''):
            break
        print(cells.text)
# Out:
# Alpine
#  64
# Gannawarra
#  41
# Mansfield
#  30
# Queenscliffe
#  14
# Ararat
#  59
# Glen Eira
#  444
# Maribyrnong
#  269
# South Gippsland
#  145
# Ballarat
#  397
# Glenelg
#  81
# Maroondah
#  426
# Southern Grampians
#  67
# Banyule
#  513
# Golden Plains
#  118
# Melbourne
#  109
# Stonnington
#  182
# Bass Coast
#  146
# Greater Bendigo
#  458
# Melton
#  659
# Strathbogie
#  42
# Baw Baw
#  237
# Greater Dandenong
#  607
# Mildura
#  271
# Surf Coast
#  148
# Bayside
#  386
# Greater Geelong
#  888
# Mitchell
#  214
# Swan Hill
#  89
# Benalla
#  33
# Greater Shepparton
#  361
# Moira
#  79
# Towong
#  30
# Boroondara
#  634
# Hepburn
#  64
# Monash
#  799
# Unincorporated Vic
#  2
# Brimbank
#  831
# Hindmarsh
#  26
# Moonee Valley
#  381
# Wangaratta
#  119
# Buloke
#  35
# Hobsons Bay
#  376
# Moorabool
#  159
# Warrnambool
#  105
# Campaspe
#  148
# Horsham
#  80
# Moreland
#  444
# Wellington
#  184
# Cardinia
#  463
# Hume
#  962
# Mornington Peninsula
#  708
# West Wimmera
#  20
# Casey
#  1,591
# Indigo
#  67
# Mount Alexander
#  77
# Whitehorse
#  637
# Central Goldfields
#  59
# Kingston
#  577
# Moyne
#  68
# Whittlesea
#  839
# Colac-Otway
#  86
# Knox
#  550
# Murrindindi
#  58
# Wodonga
#  167
# Corangamite
#  69
# Latrobe
#  332
# Nillumbik
#  302
# Wyndham
#  928
# Darebin
#  508
# Loddon
#  40
# Northern Grampians
#  48
# Yarra
#  305
# East Gippsland
#  201
# Macedon Ranges
#  206
# Port Phillip
#  240
# Yarra Ranges
#  679
# Frankston
#  577
# Manningham
#  434
# Pyrenees
#  33
# Yarriambiack
#  34

# %%
# processes a table in the TSDR data set and returns it as a dictionary
def teacherSupply(n):
    data = {}

    for row in doc.tables[n].rows[1:len(doc.tables[n].rows)]:
        for i in range(0,len(row.cells), 2):
            if(row.cells[i].text == ''):
                break
            data[row.cells[i].text] = row.cells[i+1].text
    return data

# %%
# primary school
catholic = teacherSupply(149)

# %%
government = teacherSupply(124)

# %%
pd.DataFrame([government, catholic])
# Out:
#   Alpine Gannawarra Mansfield Queenscliffe Ararat Glen Eira Maribyrnong  \
# 0    64         41        30           14     59       444         269
# 1   30.5       17.8       NaN          8.4   56.4     213.4       206.1
#
#   South Gippsland Ballarat Glenelg  ... Port Phillip Yarra Ranges Frankston  \
# 0            145      397      81   ...         240          679       577
# 1              71    464.3    18.7  ...        123.4        295.8     162.8
#
#   Manningham Pyrenees Yarriambiack Alberton Unknown LGA Camperdown Delatite
# 0       434       33           34       NaN         NaN        NaN      NaN
# 1      349.9      NaN         12.5    111.3        81.6       28.9     67.9
#
# [2 rows x 84 columns]

# %%
df = pd.DataFrame([government, catholic]).transpose()

# %%
df
# Out:
#                  0      1
# Alpine         64    30.5
# Gannawarra     41    17.8
# Mansfield      30     NaN
# Queenscliffe   14     8.4
# Ararat         59    56.4
# ...            ...    ...
# Yarriambiack   34    12.5
# Alberton       NaN  111.3
# Unknown LGA    NaN   81.6
# Camperdown     NaN   28.9
# Delatite       NaN   67.9
#
# [84 rows x 2 columns]

# %%
df[df[0].isnull()]
# Out:
#                0      1
# Alberton     NaN  111.3
# Unknown LGA  NaN   81.6
# Camperdown   NaN   28.9
# Delatite     NaN   67.9

# %%
df[df[1].isnull()]
# Out:
#                        0    1
# Mansfield            30   NaN
# Unincorporated Vic    2   NaN
# Pyrenees             33   NaN

# %%
{'abc':1,'asd':2}.keys()
# Out:
# dict_keys(['abc', 'asd'])

# %%
def tsdrTable(n):
    data = {}

    for row in doc.tables[n].rows[1:len(doc.tables[n].rows)]:
        for i in range(0,len(row.cells), 2):
            if(row.cells[i].text == ''):
                break
            data[row.cells[i].text] = row.cells[i+1].text
    return data

tableIndex = {'ecTeachers':59, 'ecStudents':64, 'psGovTeachers':124, 'psCTeachers':149, 'psStudents':158,
                   'ssGovTeachers':219, 'ssCTeachers':244, 'ssStudents':253}

df = pd.DataFrame([tsdrTable(i) for i in tableIndex.values()]).transpose()
df.columns = list(tableIndex.keys())
df = df.dropna()

# %%
# convert to numeric
df = df.replace('<5', '2.5')

# %%
df
# Out:
#                ecTeachers ecStudents psGovTeachers psCTeachers psStudents  \
# Alpine                  8        140           64         30.5     2,176
# Gannawarra              5         99           41         17.8     1,223
# Queenscliffe          2.5         57           14          8.4       262
# Ararat                  8        121           59         56.4     1,857
# Glen Eira             110      1,703          444        213.4    13,761
# ...                   ...        ...           ...         ...        ...
# Macedon Ranges         36        670          206        147.2     4,286
# Port Phillip           72        888          240        123.4     4,922
# Yarriambiack          2.5         81           34         12.5       424
# Frankston              93      1,886          577        162.8    11,655
# Manningham             81      1,292          434        349.9    10,294
#
#                ssGovTeachers ssCTeachers ssStudents
# Alpine                   78         30.5     2,301
# Gannawarra               49         17.8       572
# Queenscliffe               0         8.4          0
# Ararat                   31         56.4     1,956
# Glen Eira               328        213.4     9,747
# ...                      ...         ...        ...
# Macedon Ranges          115        147.2     4,958
# Port Phillip            224        123.4     3,892
# Yarriambiack             51         12.5       245
# Frankston               562        162.8     9,348
# Manningham              323        349.9     6,802
#
# [77 rows x 8 columns]

# %%
df = df.apply(lambda x: x.str.replace(',', ''), axis = 1)
df
# Out:
#                ecTeachers ecStudents psGovTeachers psCTeachers psStudents  \
# Alpine                  8        140           64         30.5      2176
# Gannawarra              5         99           41         17.8      1223
# Queenscliffe          2.5         57           14          8.4       262
# Ararat                  8        121           59         56.4      1857
# Glen Eira             110       1703          444        213.4     13761
# ...                   ...        ...           ...         ...        ...
# Macedon Ranges         36        670          206        147.2      4286
# Port Phillip           72        888          240        123.4      4922
# Yarriambiack          2.5         81           34         12.5       424
# Frankston              93       1886          577        162.8     11655
# Manningham             81       1292          434        349.9     10294
#
#                ssGovTeachers ssCTeachers ssStudents
# Alpine                   78         30.5      2301
# Gannawarra               49         17.8       572
# Queenscliffe               0         8.4          0
# Ararat                   31         56.4      1956
# Glen Eira               328        213.4      9747
# ...                      ...         ...        ...
# Macedon Ranges          115        147.2      4958
# Port Phillip            224        123.4      3892
# Yarriambiack             51         12.5       245
# Frankston               562        162.8      9348
# Manningham              323        349.9      6802
#
# [77 rows x 8 columns]

# %%
df = df.apply(pd.to_numeric)

# %%
prop = df['psGovTeachers'] / (df['psGovTeachers'] + df['ssGovTeachers'])

# %%
prop.mean()
# Out:
# 0.5478868579738082

# %%
plt.scatter(df['ecStudents'], df['ecStudents'] / df['ecTeachers'])
plt.xscale("log")
